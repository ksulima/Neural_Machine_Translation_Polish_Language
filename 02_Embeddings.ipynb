# %% [markdown]
# # Embeddings

# %% [markdown]
# ### Setup

# %%
from google.colab import drive
import sys, os

# %reload_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
import re
import time
from contextlib import contextmanager
from sklearn.externals import joblib

# %%
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
os.getcwd()
# Out:
# '/content/gdrive/My Drive/LSTM-light'

# %%
# Create a symbolic link to omit issues with whitespace in "My Drive"
# !ln -s /content/gdrive/"My Drive"/ /MyDrive

# %%
PROJECT_HOME_PATH = os.path.join('/MyDrive', 'LSTM-light')

# %%
cd '/MyDrive/LSTM-light'
# Out:
# /content/gdrive/My Drive/LSTM-light

# %%
os.chdir(PROJECT_HOME_PATH)

# %%
DATA_PATH = os.path.join(PROJECT_HOME_PATH, 'DATA')

# %%
pd.set_option('display.max_colwidth', -1)

# %%
@contextmanager
def elapsed_time():
  start_time = time.time()
  yield
  end_time = time.time()
  elapsed_time = end_time - start_time
  print(f'Time took: {elapsed_time}')

# %% [markdown]
# ### Load dataset

# %%
df_data = joblib.load(os.path.join(DATA_PATH, 'interim', 'quora_mod.dat'))

# %%
df_data.head()
# Out:
#                     qid  \
# 0  00002165364db923c7e6
# 1  000032939017120e6e44
# 2  0000412ca6e4628ce2cf
# 3  000042bf85aa498cd78e
# 4  0000455dfa3e01eae3af
#
#                                                                        question_text  \
# 0  How did Quebec nationalists see their province as a nation in the 1960s?
# 1  Do you have an adopted dog, how would you encourage people to adopt and not shop?
# 2  Why does velocity affect time? Does velocity affect space geometry?
# 3  How did Otto von Guericke used the Magdeburg hemispheres?
# 4  Can I convert montra helicon D to a mountain bike by just changing the tyres?
#
#                                      question_text_mod  target
# 0  quebec nationalists see province nation              0
# 1  adopted dog would encourage people adopt shop        0
# 2  velocity affect time velocity affect space geometry  0
# 3  otto von guericke used magdeburg hemispheres         0
# 4  convert montra helicon mountain bike changing tyres  0

# %%
notes = df_data.question_text_mod

# %%
notes = list(notes)

# %%
len(notes)
# Out:
# 1305497

# %%
notes[:10]
# Out:
# ['quebec nationalists see province nation',
#  'adopted dog would encourage people adopt shop',
#  'velocity affect time velocity affect space geometry',
#  'otto von guericke used magdeburg hemispheres',
#  'convert montra helicon mountain bike changing tyres',
#  'gaza slowly becoming auschwitz dachau treblinka palestinians',
#  'quora automatically ban conservative opinions reported liberal views',
#  'crazy wash wipe groceries germs everywhere',
#  'thing dressing moderately different dressing modestly',
#  'ever phase wherein became ignorant people loved completely disregarding feelings lives get something go way feel temporarily ease things change']

# %% [markdown]
# ### Subwords

# %% [markdown]
# In this step we use *Subwords Neural Translation* method to generate subwords.
#
# Souce: https://github.com/rsennrich/subword-nmt

# %%
# !pip install subword-nmt
# Out:
# Collecting subword-nmt
#   Downloading https://files.pythonhosted.org/packages/26/08/58267cb3ac00f5f895457777ed9e0d106dbb5e6388fa7923d8663b04b849/subword_nmt-0.3.6-py2.py3-none-any.whl
# Installing collected packages: subword-nmt
# Successfully installed subword-nmt-0.3.6

# %%
import collections
import tempfile
from subword_nmt.learn_joint_bpe_and_vocab import learn_joint_bpe_and_vocab

# %%
Path = collections.namedtuple('Path', ['name'])


class LearnJointBpeVocabArgs:
    """
    Helper for passing arguments to ``learn_joint_bpe_and_vocab``. This class
    needs to exists because logic in ``learn_joint_bpe_and_vocab.py`` is designed
    that way.
    """  
    
    def __init__(self, input_, output, vocab, symbols=10000, min_frequency=5, verbose=False, separator='@@', total_symbols=1000):
      self.input=[Path(input_)]
      self.output = Path(output)
      self.vocab = [Path(vocab)]
      self.symbols = symbols
      self.min_frequency = min_frequency
      self.verbose = verbose
      self.separator = separator
      self.total_symbols = total_symbols

        
def generate_subwords_vocab(notes, output_codes_path, output_vocab_path, symbols=10000, 
                           min_frequency=5, verbose=False, separator='@@', total_symbols=1000):
  
    # temp file used here because learn_joint_bpe_and_vocab does not accept anything other than file
    with tempfile.NamedTemporaryFile('wt', encoding='utf-8', delete=False) as notes_temp_file:
        notes_temp_file.writelines(note + '\n' for note in notes)
        notes_temp_file_path = notes_temp_file.name
        
        
    # this function qutomatically saves the result
    learn_joint_bpe_and_vocab(LearnJointBpeVocabArgs(
        input_ = notes_temp_file_path,
        output = output_codes_path,
        vocab = output_vocab_path,
        verbose = verbose,
        symbols = symbols,
        min_frequency = min_frequency,
        separator = separator,
        total_symbols = total_symbols
    ))
  
  
    os.remove(notes_temp_file_path)

# %%
CODES_PATH = os.path.join(PROJECT_HOME_PATH, 'subwords', 'codes.txt')
VOCAB_PATH = os.path.join(PROJECT_HOME_PATH, 'subwords', 'vocab.txt')

# %%
generate_subwords_vocab(
    notes=notes,
    output_codes_path = CODES_PATH,
    output_vocab_path = VOCAB_PATH,
    verbose=True,
    symbols=10000,
    min_frequency=5,
    total_symbols=1000
)
# Out:
# Number of word-internal characters: 26
# Number of word-final characters: 26
# Reducing number of merge operations by 52
# pair 0: i n -> in (frequency 956914)
# pair 1: r e -> re (frequency 579112)
# pair 2: a n -> an (frequency 505586)
# pair 3: t i -> ti (frequency 480881)
# pair 4: e r -> er (frequency 479279)
# pair 5: e n -> en (frequency 447372)
# pair 6: o n -> on (frequency 439299)
# pair 7: in g</w> -> ing</w> (frequency 405597)
# pair 8: a r -> ar (frequency 395912)
# pair 9: s t -> st (frequency 353751)
# pair 10: o r -> or (frequency 352285)
# pair 11: l i -> li (frequency 320553)
# pair 12: e r</w> -> er</w> (frequency 305731)
# pair 13: a t -> at (frequency 305446)
# pair 14: e s</w> -> es</w> (frequency 297127)
# pair 15: o u -> ou (frequency 292979)
# pair 16: e d</w> -> ed</w> (frequency 285813)
# pair 17: a l -> al (frequency 254308)
# pair 18: o n</w> -> on</w> (frequency 250868)
# pair 19: s i -> si (frequency 241751)
# pair 20: a c -> ac (frequency 240895)
# pair 21: o m -> om (frequency 237898)
# pair 22: e s -> es (frequency 226921)
# pair 23: d i -> di (frequency 218548)
# pair 24: r i -> ri (frequency 210162)
# pair 25: a l</w> -> al</w> (frequency 198107)
# pair 26: r o -> ro (frequency 193681)
# pair 27: t h -> th (frequency 190694)
# pair 28: c h -> ch (frequency 189126)
# pair 29: l e</w> -> le</w> (frequency 186314)
# pair 30: e l -> el (frequency 172225)
# pair 31: e c -> ec (frequency 166760)
# pair 32: a s -> as (frequency 154786)
# pair 33: o o -> oo (frequency 151486)
# pair 34: m a -> ma (frequency 147243)
# pair 35: r a -> ra (frequency 144624)
# pair 36: l e -> le (frequency 140378)
# pair 37: u s -> us (frequency 137877)
# pair 38: ti on</w> -> tion</w> (frequency 136534)
# pair 39: i c -> ic (frequency 132695)
# pair 40: o p -> op (frequency 131964)
# pair 41: l o -> lo (frequency 131039)
# pair 42: d e -> de (frequency 130607)
# pair 43: l d</w> -> ld</w> (frequency 126113)
# pair 44: u r -> ur (frequency 124339)
# pair 45: l y</w> -> ly</w> (frequency 119259)
# pair 46: a m -> am (frequency 119192)
# pair 47: t s</w> -> ts</w> (frequency 117817)
# pair 48: v e</w> -> ve</w> (frequency 114935)
# pair 49: k e</w> -> ke</w> (frequency 112471)
# pair 50: l a -> la (frequency 111531)
# pair 51: e t</w> -> et</w> (frequency 109684)
# pair 52: c e</w> -> ce</w> (frequency 106203)
# pair 53: u n -> un (frequency 104681)
# pair 54: i s -> is (frequency 102968)
# pair 55: a p -> ap (frequency 101782)
# pair 56: a n</w> -> an</w> (frequency 101558)
# pair 57: en t</w> -> ent</w> (frequency 101508)
# pair 58: p e -> pe (frequency 101275)
# pair 59: i t -> it (frequency 101272)
# pair 60: c om -> com (frequency 101082)
# pair 61: es t</w> -> est</w> (frequency 100198)
# pair 62: p ro -> pro (frequency 97728)
# pair 63: p o -> po (frequency 96596)
# pair 64: e x -> ex (frequency 96458)
# pair 65: on e</w> -> one</w> (frequency 95353)
# pair 66: c on -> con (frequency 88279)
# pair 67: t r -> tr (frequency 86628)
# pair 68: m e -> me (frequency 85693)
# pair 69: v i -> vi (frequency 85603)
# pair 70: a g -> ag (frequency 85478)
# pair 71: q u -> qu (frequency 80862)
# pair 72: v er -> ver (frequency 79897)
# pair 73: s h -> sh (frequency 79664)
# pair 74: o l -> ol (frequency 79346)
# pair 75: s u -> su (frequency 79183)
# pair 76: f e -> fe (frequency 79181)
# pair 77: ou ld</w> -> ould</w> (frequency 78026)
# pair 78: n e -> ne (frequency 77666)
# pair 79: a d -> ad (frequency 76516)
# pair 80: w or -> wor (frequency 76465)
# pair 81: a y</w> -> ay</w> (frequency 76451)
# pair 82: m o -> mo (frequency 75154)
# pair 83: at e</w> -> ate</w> (frequency 74861)
# pair 84: i r -> ir (frequency 74608)
# pair 85: p er -> per (frequency 72047)
# pair 86: ti on -> tion (frequency 71826)
# pair 87: i l -> il (frequency 71595)
# pair 88: er s</w> -> ers</w> (frequency 70523)
# pair 89: s e -> se (frequency 70145)
# pair 90: e n</w> -> en</w> (frequency 69094)
# pair 91: t a -> ta (frequency 68934)
# pair 92: c i -> ci (frequency 67693)
# pair 93: g h -> gh (frequency 67634)
# pair 94: ou n -> oun (frequency 67439)
# pair 95: g et</w> -> get</w> (frequency 66059)
# pair 96: a r</w> -> ar</w> (frequency 64158)
# pair 97: n o -> no (frequency 64106)
# pair 98: b est</w> -> best</w> (frequency 62669)
# pair 99: i n</w> -> in</w> (frequency 62546)
# pair 100: u c -> uc (frequency 62215)
# pair 101: a b -> ab (frequency 61723)
# pair 102: p re -> pre (frequency 61619)
# pair 103: w ould</w> -> would</w> (frequency 61534)
# pair 104: s e</w> -> se</w> (frequency 61001)
# pair 105: re n -> ren (frequency 60800)
# pair 106: m an -> man (frequency 60181)
# pair 107: e t -> et (frequency 59284)
# pair 108: s p -> sp (frequency 57215)
# pair 109: pe op -> peop (frequency 56870)
# pair 110: peop le</w> -> people</w> (frequency 56499)
# pair 111: in di -> indi (frequency 55682)
# pair 112: t er -> ter (frequency 54710)
# pair 113: t e -> te (frequency 54528)
# pair 114: s t</w> -> st</w> (frequency 54181)
# pair 115: a tion</w> -> ation</w> (frequency 53602)
# pair 116: oo d</w> -> ood</w> (frequency 53059)
# pair 117: t o -> to (frequency 52802)
# pair 118: i m -> im (frequency 52495)
# pair 119: c o -> co (frequency 52441)
# pair 120: u l -> ul (frequency 52091)
# pair 121: li ke</w> -> like</w> (frequency 50877)
# pair 122: t y</w> -> ty</w> (frequency 50344)
# pair 123: p h -> ph (frequency 50280)
# pair 124: t er</w> -> ter</w> (frequency 49890)
# pair 125: d s</w> -> ds</w> (frequency 49692)
# pair 126: t h</w> -> th</w> (frequency 48366)
# pair 127: u m -> um (frequency 47916)
# pair 128: w e -> we (frequency 47628)
# pair 129: e m -> em (frequency 47616)
# pair 130: al ly</w> -> ally</w> (frequency 47209)
# pair 131: f f -> ff (frequency 47042)
# pair 132: an t</w> -> ant</w> (frequency 46983)
# pair 133: p l -> pl (frequency 46709)
# pair 134: an g -> ang (frequency 46162)
# pair 135: com p -> comp (frequency 46052)
# pair 136: d e</w> -> de</w> (frequency 46004)
# pair 137: a d</w> -> ad</w> (frequency 45095)
# pair 138: f i -> fi (frequency 43676)
# pair 139: g i -> gi (frequency 43649)
# pair 140: e v -> ev (frequency 43628)
# pair 141: t ing</w> -> ting</w> (frequency 43458)
# pair 142: m ar -> mar (frequency 42920)
# pair 143: t u -> tu (frequency 41949)
# pair 144: k ing</w> -> king</w> (frequency 41925)
# pair 145: g o -> go (frequency 41336)
# pair 146: th in -> thin (frequency 40933)
# pair 147: h e -> he (frequency 40887)
# pair 148: es s</w> -> ess</w> (frequency 40603)
# pair 149: e l</w> -> el</w> (frequency 40559)
# pair 150: tion s</w> -> tions</w> (frequency 40200)
# pair 151: f or -> for (frequency 40067)
# pair 152: b i -> bi (frequency 39996)
# pair 153: b o -> bo (frequency 39891)
# pair 154: ag e</w> -> age</w> (frequency 39479)
# pair 155: j o -> jo (frequency 39267)
# pair 156: gh t</w> -> ght</w> (frequency 39095)
# pair 157: s o -> so (frequency 38841)
# pair 158: c a -> ca (frequency 38816)
# pair 159: u d -> ud (frequency 38802)
# pair 160: m i -> mi (frequency 38779)
# pair 161: t e</w> -> te</w> (frequency 38755)
# pair 162: re d</w> -> red</w> (frequency 38514)
# pair 163: g ood</w> -> good</w> (frequency 38513)
# pair 164: in e</w> -> ine</w> (frequency 38428)
# pair 165: ur e</w> -> ure</w> (frequency 38137)
# pair 166: a y -> ay (frequency 38077)
# pair 167: h i -> hi (frequency 37902)
# pair 168: p ar -> par (frequency 37888)
# pair 169: om e -> ome (frequency 37721)
# pair 170: u s</w> -> us</w> (frequency 37698)
# pair 171: k s</w> -> ks</w> (frequency 36636)
# pair 172: g ra -> gra (frequency 36330)
# pair 173: ti m -> tim (frequency 36301)
# pair 174: en g -> eng (frequency 36286)
# pair 175: a i -> ai (frequency 35870)
# pair 176: b le</w> -> ble</w> (frequency 35834)
# pair 177: ti c -> tic (frequency 35501)
# pair 178: s ome -> some (frequency 35193)
# pair 179: b e -> be (frequency 34911)
# pair 180: t ed</w> -> ted</w> (frequency 34827)
# pair 181: y e -> ye (frequency 34664)
# pair 182: p or -> por (frequency 34440)
# pair 183: c oun -> coun (frequency 34208)
# pair 184: f in -> fin (frequency 33860)
# pair 185: an s</w> -> ans</w> (frequency 33034)
# pair 186: indi a</w> -> india</w> (frequency 32895)
# pair 187: a li -> ali (frequency 32209)
# pair 188: a t</w> -> at</w> (frequency 32161)
# pair 189: k no -> kno (frequency 31900)
# pair 190: w i -> wi (frequency 31685)
# pair 191: ap p -> app (frequency 31629)
# pair 192: f fe -> ffe (frequency 31507)
# pair 193: m ent</w> -> ment</w> (frequency 31347)
# pair 194: en ce</w> -> ence</w> (frequency 31235)
# pair 195: en d</w> -> end</w> (frequency 31097)
# pair 196: g e</w> -> ge</w> (frequency 30923)
# pair 197: f e</w> -> fe</w> (frequency 30853)
# pair 198: g s</w> -> gs</w> (frequency 30842)
# pair 199: m on -> mon (frequency 30421)
# pair 200: d u -> du (frequency 29892)
# pair 201: d o -> do (frequency 29613)
# pair 202: us e</w> -> use</w> (frequency 29577)
# pair 203: c h</w> -> ch</w> (frequency 29558)
# pair 204: s ti -> sti (frequency 29549)
# pair 205: b u -> bu (frequency 29352)
# pair 206: ti ve</w> -> tive</w> (frequency 29120)
# pair 207: f ri -> fri (frequency 29038)
# pair 208: st r -> str (frequency 28790)
# pair 209: ffe ren -> fferen (frequency 28741)
# pair 210: s c -> sc (frequency 28696)
# pair 211: di fferen -> differen (frequency 28633)
# pair 212: on g</w> -> ong</w> (frequency 28578)
# pair 213: en ts</w> -> ents</w> (frequency 28441)
# pair 214: ma ke</w> -> make</w> (frequency 28397)
# pair 215: g u -> gu (frequency 27823)
# pair 216: man y</w> -> many</w> (frequency 27813)
# pair 217: st ud -> stud (frequency 27807)
# pair 218: th ing</w> -> thing</w> (frequency 27713)
# pair 219: w ay</w> -> way</w> (frequency 27691)
# pair 220: a v -> av (frequency 27064)
# pair 221: t ra -> tra (frequency 27039)
# pair 222: t ri -> tri (frequency 27012)
# pair 223: b oo -> boo (frequency 26922)
# pair 224: f u -> fu (frequency 26767)
# pair 225: ac k</w> -> ack</w> (frequency 26765)
# pair 226: om e</w> -> ome</w> (frequency 26343)
# pair 227: ec t</w> -> ect</w> (frequency 26176)
# pair 228: thin k</w> -> think</w> (frequency 26139)
# pair 229: h o -> ho (frequency 26015)
# pair 230: c l -> cl (frequency 25981)
# pair 231: st ar -> star (frequency 25822)
# pair 232: n i -> ni (frequency 25780)
# pair 233: tim e</w> -> time</w> (frequency 25737)
# pair 234: ay s</w> -> ays</w> (frequency 25685)
# pair 235: at ed</w> -> ated</w> (frequency 25465)
# pair 236: s y -> sy (frequency 25434)
# pair 237: s er -> ser (frequency 25417)
# pair 238: c ol -> col (frequency 25403)
# pair 239: m in -> min (frequency 25398)
# pair 240: f ac -> fac (frequency 25326)
# pair 241: p a -> pa (frequency 25325)
# pair 242: g re -> gre (frequency 25265)
# pair 243: d ing</w> -> ding</w> (frequency 25256)
# pair 244: th ou -> thou (frequency 25166)
# pair 245: an ce</w> -> ance</w> (frequency 24916)
# pair 246: an d</w> -> and</w> (frequency 24768)
# pair 247: ou r -> our (frequency 24469)
# pair 248: per s -> pers (frequency 24244)
# pair 249: m s</w> -> ms</w> (frequency 24191)
# pair 250: d er</w> -> der</w> (frequency 24175)
# pair 251: st e -> ste (frequency 24159)
# pair 252: it y</w> -> ity</w> (frequency 24100)
# pair 253: ar d</w> -> ard</w> (frequency 24058)
# pair 254: c re -> cre (frequency 23923)
# pair 255: d er -> der (frequency 23881)
# pair 256: un i -> uni (frequency 23815)
# pair 257: m uc -> muc (frequency 23686)
# pair 258: muc h</w> -> much</w> (frequency 23490)
# pair 259: p u -> pu (frequency 23265)
# pair 260: s si -> ssi (frequency 23242)
# pair 261: li fe</w> -> life</w> (frequency 23141)
# pair 262: a u -> au (frequency 23063)
# pair 263: en t -> ent (frequency 22965)
# pair 264: some one</w> -> someone</w> (frequency 22799)
# pair 265: b l -> bl (frequency 22762)
# pair 266: l s</w> -> ls</w> (frequency 22565)
# pair 267: el l</w> -> ell</w> (frequency 22397)
# pair 268: re c -> rec (frequency 22325)
# pair 269: ar s</w> -> ars</w> (frequency 22200)
# pair 270: wor k</w> -> work</w> (frequency 22187)
# pair 271: ar y</w> -> ary</w> (frequency 22174)
# pair 272: al l</w> -> all</w> (frequency 22136)
# pair 273: sh i -> shi (frequency 22110)
# pair 274: v el -> vel (frequency 22014)
# pair 275: ar e</w> -> are</w> (frequency 22014)
# pair 276: ma n</w> -> man</w> (frequency 21736)
# pair 277: b ec -> bec (frequency 21565)
# pair 278: n a -> na (frequency 21534)
# pair 279: am er -> amer (frequency 21465)
# pair 280: p s</w> -> ps</w> (frequency 21437)
# pair 281: es s -> ess (frequency 21351)
# pair 282: d uc -> duc (frequency 21218)
# pair 283: com m -> comm (frequency 21193)
# pair 284: ab le</w> -> able</w> (frequency 21077)
# pair 285: ou s</w> -> ous</w> (frequency 20970)
# pair 286: in ter -> inter (frequency 20903)
# pair 287: m at -> mat (frequency 20897)
# pair 288: i es</w> -> ies</w> (frequency 20791)
# pair 289: an d -> and (frequency 20786)
# pair 290: r u -> ru (frequency 20744)
# pair 291: kno w</w> -> know</w> (frequency 20537)
# pair 292: ch oo -> choo (frequency 20378)
# pair 293: d ay</w> -> day</w> (frequency 20268)
# pair 294: a m</w> -> am</w> (frequency 20095)
# pair 295: le ar -> lear (frequency 20006)
# pair 296: k e -> ke (frequency 19940)
# pair 297: g h</w> -> gh</w> (frequency 19778)
# pair 298: lo g -> log (frequency 19687)
# pair 299: g ir -> gir (frequency 19664)
# pair 300: ev er</w> -> ever</w> (frequency 19647)
# pair 301: amer ic -> americ (frequency 19572)
# pair 302: or e</w> -> ore</w> (frequency 19502)
# pair 303: as t</w> -> ast</w> (frequency 19422)
# pair 304: in e -> ine (frequency 19417)
# pair 305: ic e</w> -> ice</w> (frequency 19319)
# pair 306: p la -> pla (frequency 19222)
# pair 307: t w -> tw (frequency 19192)
# pair 308: w om -> wom (frequency 19080)
# pair 309: ta ke</w> -> take</w> (frequency 19063)
# pair 310: w ant</w> -> want</w> (frequency 18864)
# pair 311: g en -> gen (frequency 18829)
# pair 312: c e -> ce (frequency 18826)
# pair 313: or y</w> -> ory</w> (frequency 18791)
# pair 314: p r -> pr (frequency 18528)
# pair 315: i c</w> -> ic</w> (frequency 18526)
# pair 316: am e</w> -> ame</w> (frequency 18511)
# pair 317: si on</w> -> sion</w> (frequency 18424)
# pair 318: ac h -> ach (frequency 18350)
# pair 319: di s -> dis (frequency 18331)
# pair 320: g r -> gr (frequency 18243)
# pair 321: y ing</w> -> ying</w> (frequency 18222)
# pair 322: u e</w> -> ue</w> (frequency 18185)
# pair 323: w s</w> -> ws</w> (frequency 18119)
# pair 324: w h -> wh (frequency 18100)
# pair 325: p ri -> pri (frequency 17961)
# pair 326: an y -> any (frequency 17957)
# pair 327: ti es</w> -> ties</w> (frequency 17895)
# pair 328: as e</w> -> ase</w> (frequency 17871)
# pair 329: st o -> sto (frequency 17721)
# pair 330: an s -> ans (frequency 17670)
# pair 331: tr y</w> -> try</w> (frequency 17493)
# pair 332: b et -> bet (frequency 17470)
# pair 333: al s</w> -> als</w> (frequency 17454)
# pair 334: wor ld</w> -> world</w> (frequency 17440)
# pair 335: oun d</w> -> ound</w> (frequency 17437)
# pair 336: fin d</w> -> find</w> (frequency 17436)
# pair 337: c u -> cu (frequency 17428)
# pair 338: v er</w> -> ver</w> (frequency 17384)
# pair 339: g o</w> -> go</w> (frequency 17315)
# pair 340: i st -> ist (frequency 17283)
# pair 341: f ir -> fir (frequency 17227)
# pair 342: qu or -> quor (frequency 17203)
# pair 343: ac e</w> -> ace</w> (frequency 17197)
# pair 344: it e</w> -> ite</w> (frequency 17161)
# pair 345: s a -> sa (frequency 17146)
# pair 346: n ing</w> -> ning</w> (frequency 17106)
# pair 347: th er</w> -> ther</w> (frequency 17076)
# pair 348: on s</w> -> ons</w> (frequency 17016)
# pair 349: bec ome</w> -> become</w> (frequency 17004)
# pair 350: i d</w> -> id</w> (frequency 16981)
# pair 351: me di -> medi (frequency 16941)
# pair 352: t ure</w> -> ture</w> (frequency 16928)
# pair 353: pers on</w> -> person</w> (frequency 16855)
# pair 354: c an -> can (frequency 16805)
# pair 355: f re -> fre (frequency 16733)
# pair 356: thou t</w> -> thout</w> (frequency 16718)
# pair 357: us ed</w> -> used</w> (frequency 16709)
# pair 358: wi thout</w> -> without</w> (frequency 16705)
# pair 359: e ver -> ever (frequency 16633)
# pair 360: h u -> hu (frequency 16543)
# pair 361: po ssi -> possi (frequency 16504)
# pair 362: um p</w> -> ump</w> (frequency 16430)
# pair 363: c ould</w> -> could</w> (frequency 16389)
# pair 364: ic al</w> -> ical</w> (frequency 16338)
# pair 365: ye ar</w> -> year</w> (frequency 16253)
# pair 366: fe el</w> -> feel</w> (frequency 16243)
# pair 367: y p -> yp (frequency 16235)
# pair 368: s s</w> -> ss</w> (frequency 16215)
# pair 369: la r</w> -> lar</w> (frequency 16144)
# pair 370: eng ine -> engine (frequency 16128)
# pair 371: bet ter</w> -> better</w> (frequency 16059)
# pair 372: v e -> ve (frequency 16045)
# pair 373: boo k</w> -> book</w> (frequency 16019)
# pair 374: con t -> cont (frequency 16005)
# pair 375: tion al</w> -> tional</w> (frequency 15966)
# pair 376: quor a</w> -> quora</w> (frequency 15954)
# pair 377: o r</w> -> or</w> (frequency 15946)
# pair 378: s in -> sin (frequency 15883)
# pair 379: w ri -> wri (frequency 15872)
# pair 380: si g -> sig (frequency 15814)
# pair 381: ch ang -> chang (frequency 15760)
# pair 382: at ing</w> -> ating</w> (frequency 15741)
# pair 383: c es</w> -> ces</w> (frequency 15736)
# pair 384: so ci -> soci (frequency 15660)
# pair 385: as s</w> -> ass</w> (frequency 15652)
# pair 386: s h</w> -> sh</w> (frequency 15601)
# pair 387: l oo -> loo (frequency 15503)
# pair 388: or s</w> -> ors</w> (frequency 15467)
# pair 389: uni ver -> univer (frequency 15411)
# pair 390: per i -> peri (frequency 15378)
# pair 391: el ec -> elec (frequency 15375)
# pair 392: l ine</w> -> line</w> (frequency 15360)
# pair 393: li c -> lic (frequency 15359)
# pair 394: ne w</w> -> new</w> (frequency 15315)
# pair 395: a s</w> -> as</w> (frequency 15286)
# pair 396: fu l</w> -> ful</w> (frequency 15260)
# pair 397: s ec -> sec (frequency 15237)
# pair 398: c ri -> cri (frequency 15233)
# pair 399: comp an -> compan (frequency 15226)
# pair 400: ti c</w> -> tic</w> (frequency 15133)
# pair 401: possi ble</w> -> possible</w> (frequency 14983)
# pair 402: t ur -> tur (frequency 14982)
# pair 403: h el -> hel (frequency 14955)
# pair 404: s choo -> schoo (frequency 14936)
# pair 405: m us -> mus (frequency 14902)
# pair 406: w er</w> -> wer</w> (frequency 14881)
# pair 407: w at -> wat (frequency 14857)
# pair 408: l l</w> -> ll</w> (frequency 14850)
# pair 409: v ing</w> -> ving</w> (frequency 14785)
# pair 410: tr ump</w> -> trump</w> (frequency 14762)
# pair 411: at h -> ath (frequency 14740)
# pair 412: c r -> cr (frequency 14708)
# pair 413: ch in -> chin (frequency 14696)
# pair 414: en ti -> enti (frequency 14689)
# pair 415: sh o -> sho (frequency 14688)
# pair 416: w ays</w> -> ways</w> (frequency 14680)
# pair 417: shi p</w> -> ship</w> (frequency 14628)
# pair 418: col le -> colle (frequency 14610)
# pair 419: b er</w> -> ber</w> (frequency 14478)
# pair 420: c ur -> cur (frequency 14440)
# pair 421: ch ar -> char (frequency 14413)
# pair 422: jo b</w> -> job</w> (frequency 14376)
# pair 423: b r -> br (frequency 14354)
# pair 424: a si -> asi (frequency 14285)
# pair 425: t re -> tre (frequency 14272)
# pair 426: h app -> happ (frequency 14246)
# pair 427: s ci -> sci (frequency 14229)
# pair 428: g e -> ge (frequency 14204)
# pair 429: por t -> port (frequency 14196)
# pair 430: fri end</w> -> friend</w> (frequency 14178)
# pair 431: er ing</w> -> ering</w> (frequency 14157)
# pair 432: ye ars</w> -> years</w> (frequency 14066)
# pair 433: f ic -> fic (frequency 14022)
# pair 434: b us -> bus (frequency 14005)
# pair 435: e y</w> -> ey</w> (frequency 13882)
# pair 436: j e -> je (frequency 13876)
# pair 437: is t</w> -> ist</w> (frequency 13868)
# pair 438: n or -> nor (frequency 13826)
# pair 439: al l -> all (frequency 13748)
# pair 440: indi an</w> -> indian</w> (frequency 13701)
# pair 441: me an</w> -> mean</w> (frequency 13672)
# pair 442: u p -> up (frequency 13646)
# pair 443: re s</w> -> res</w> (frequency 13618)
# pair 444: d re -> dre (frequency 13534)
# pair 445: c or -> cor (frequency 13454)
# pair 446: wom en</w> -> women</w> (frequency 13375)
# pair 447: o re -> ore (frequency 13366)
# pair 448: star t</w> -> start</w> (frequency 13333)
# pair 449: at es</w> -> ates</w> (frequency 13312)
# pair 450: o ff -> off (frequency 13269)
# pair 451: ec i -> eci (frequency 13232)
# pair 452: qu es -> ques (frequency 13201)
# pair 453: ne ed</w> -> need</w> (frequency 13197)
# pair 454: e ar -> ear (frequency 13196)
# pair 455: ad v -> adv (frequency 13175)
# pair 456: c al</w> -> cal</w> (frequency 13117)
# pair 457: o b -> ob (frequency 13074)
# pair 458: fir st</w> -> first</w> (frequency 12995)
# pair 459: ser v -> serv (frequency 12987)
# pair 460: in t -> int (frequency 12983)
# pair 461: i t</w> -> it</w> (frequency 12919)
# pair 462: lo w</w> -> low</w> (frequency 12896)
# pair 463: t t -> tt (frequency 12894)
# pair 464: u m</w> -> um</w> (frequency 12818)
# pair 465: h ar -> har (frequency 12817)
# pair 466: su p -> sup (frequency 12807)
# pair 467: in ess</w> -> iness</w> (frequency 12785)
# pair 468: ap pe -> appe (frequency 12719)
# pair 469: f t</w> -> ft</w> (frequency 12706)
# pair 470: en d -> end (frequency 12683)
# pair 471: ac t</w> -> act</w> (frequency 12509)
# pair 472: as s -> ass (frequency 12493)
# pair 473: an t -> ant (frequency 12491)
# pair 474: i l</w> -> il</w> (frequency 12473)
# pair 475: el y</w> -> ely</w> (frequency 12469)
# pair 476: differen ce</w> -> difference</w> (frequency 12459)
# pair 477: mon ey</w> -> money</w> (frequency 12439)
# pair 478: d y</w> -> dy</w> (frequency 12424)
# pair 479: de vel -> devel (frequency 12420)
# pair 480: f l -> fl (frequency 12364)
# pair 481: sti ll</w> -> still</w> (frequency 12276)
# pair 482: po li -> poli (frequency 12247)
# pair 483: schoo l</w> -> school</w> (frequency 12210)
# pair 484: il l -> ill (frequency 12210)
# pair 485: k ed</w> -> ked</w> (frequency 12191)
# pair 486: i g -> ig (frequency 12189)
# pair 487: e p</w> -> ep</w> (frequency 12180)
# pair 488: s k -> sk (frequency 12153)
# pair 489: re la -> rela (frequency 12142)
# pair 490: em ent</w> -> ement</w> (frequency 12110)
# pair 491: com e</w> -> come</w> (frequency 12086)
# pair 492: differen t</w> -> different</w> (frequency 12083)
# pair 493: con si -> consi (frequency 12061)
# pair 494: o ld</w> -> old</w> (frequency 11962)
# pair 495: e ff -> eff (frequency 11940)
# pair 496: coun try</w> -> country</w> (frequency 11886)
# pair 497: h in -> hin (frequency 11877)
# pair 498: s s -> ss (frequency 11868)
# pair 499: es e</w> -> ese</w> (frequency 11838)
# pair 500: vi e -> vie (frequency 11818)
# pair 501: l ong</w> -> long</w> (frequency 11814)
# pair 502: s ur -> sur (frequency 11789)
# pair 503: univer si -> universi (frequency 11781)
# pair 504: re ally</w> -> really</w> (frequency 11754)
# pair 505: log y</w> -> logy</w> (frequency 11751)
# pair 506: b an -> ban (frequency 11736)
# pair 507: d es -> des (frequency 11723)
# pair 508: g a -> ga (frequency 11685)
# pair 509: f un -> fun (frequency 11622)
# pair 510: m is -> mis (frequency 11595)
# pair 511: v es</w> -> ves</w> (frequency 11474)
# pair 512: lear n</w> -> learn</w> (frequency 11454)
# pair 513: st s</w> -> sts</w> (frequency 11451)
# pair 514: k es</w> -> kes</w> (frequency 11427)
# pair 515: m al -> mal (frequency 11425)
# pair 516: b er -> ber (frequency 11394)
# pair 517: bus iness</w> -> business</w> (frequency 11363)
# pair 518: f a -> fa (frequency 11319)
# pair 519: lo ve</w> -> love</w> (frequency 11310)
# pair 520: s ol -> sol (frequency 11140)
# pair 521: c our -> cour (frequency 11137)
# pair 522: c k</w> -> ck</w> (frequency 11133)
# pair 523: ai r</w> -> air</w> (frequency 11112)
# pair 524: m u -> mu (frequency 11108)
# pair 525: ex am -> exam (frequency 11103)
# pair 526: ev en</w> -> even</w> (frequency 11086)
# pair 527: us ing</w> -> using</w> (frequency 11063)
# pair 528: me n</w> -> men</w> (frequency 11033)
# pair 529: ar i -> ari (frequency 11027)
# pair 530: colle ge</w> -> college</w> (frequency 11021)
# pair 531: c ul -> cul (frequency 10972)
# pair 532: thin gs</w> -> things</w> (frequency 10962)
# pair 533: y si -> ysi (frequency 10918)
# pair 534: s pe -> spe (frequency 10896)
# pair 535: t es</w> -> tes</w> (frequency 10894)
# pair 536: v el</w> -> vel</w> (frequency 10871)
# pair 537: gi ve</w> -> give</w> (frequency 10870)
# pair 538: p i -> pi (frequency 10864)
# pair 539: t yp -> typ (frequency 10856)
# pair 540: en s</w> -> ens</w> (frequency 10842)
# pair 541: r y</w> -> ry</w> (frequency 10785)
# pair 542: g er -> ger (frequency 10767)
# pair 543: c ar -> car (frequency 10736)
# pair 544: in v -> inv (frequency 10721)
# pair 545: w n</w> -> wn</w> (frequency 10693)
# pair 546: tic s</w> -> tics</w> (frequency 10680)
# pair 547: pro gra -> progra (frequency 10645)
# pair 548: at t -> att (frequency 10645)
# pair 549: to r</w> -> tor</w> (frequency 10634)
# pair 550: engine ering</w> -> engineering</w> (frequency 10621)
# pair 551: chang e</w> -> change</w> (frequency 10484)
# pair 552: si d -> sid (frequency 10459)
# pair 553: r an -> ran (frequency 10419)
# pair 554: g le</w> -> gle</w> (frequency 10418)
# pair 555: hel p</w> -> help</w> (frequency 10385)
# pair 556: g et -> get (frequency 10383)
# pair 557: si te</w> -> site</w> (frequency 10371)
# pair 558: b ack</w> -> back</w> (frequency 10340)
# pair 559: in gs</w> -> ings</w> (frequency 10334)
# pair 560: su b -> sub (frequency 10327)
# pair 561: on line</w> -> online</w> (frequency 10299)
# pair 562: b ri -> bri (frequency 10283)
# pair 563: z e</w> -> ze</w> (frequency 10262)
# pair 564: b s</w> -> bs</w> (frequency 10244)
# pair 565: n um -> num (frequency 10218)
# pair 566: in te -> inte (frequency 10209)
# pair 567: th e -> the (frequency 10192)
# pair 568: pro duc -> produc (frequency 10183)
# pair 569: s ay</w> -> say</w> (frequency 10123)
# pair 570: se e</w> -> see</w> (frequency 10115)
# pair 571: mar k -> mark (frequency 10107)
# pair 572: st er</w> -> ster</w> (frequency 10105)
# pair 573: p le</w> -> ple</w> (frequency 10092)
# pair 574: te ch -> tech (frequency 10088)
# pair 575: ang u -> angu (frequency 10059)
# pair 576: ex p -> exp (frequency 10058)
# pair 577: ph one</w> -> phone</w> (frequency 10051)
# pair 578: b re -> bre (frequency 10027)
# pair 579: a ff -> aff (frequency 10024)
# pair 580: ex peri -> experi (frequency 10008)
# pair 581: f am -> fam (frequency 9995)
# pair 582: p t</w> -> pt</w> (frequency 9965)
# pair 583: devel op -> develop (frequency 9960)
# pair 584: b ad</w> -> bad</w> (frequency 9900)
# pair 585: i li -> ili (frequency 9818)
# pair 586: ch an -> chan (frequency 9812)
# pair 587: un der -> under (frequency 9799)
# pair 588: b le -> ble (frequency 9778)
# pair 589: p ur -> pur (frequency 9743)
# pair 590: d el -> del (frequency 9719)
# pair 591: a k -> ak (frequency 9685)
# pair 592: d ed</w> -> ded</w> (frequency 9643)
# pair 593: ch e -> che (frequency 9600)
# pair 594: ma de</w> -> made</w> (frequency 9587)
# pair 595: s el -> sel (frequency 9586)
# pair 596: universi ty</w> -> university</w> (frequency 9552)
# pair 597: ri ght</w> -> right</w> (frequency 9519)
# pair 598: lo w -> low (frequency 9518)
# pair 599: compan y</w> -> company</w> (frequency 9513)
# pair 600: v al -> val (frequency 9499)
# pair 601: ag es</w> -> ages</w> (frequency 9471)
# pair 602: ever y -> every (frequency 9469)
# pair 603: li sh</w> -> lish</w> (frequency 9458)
# pair 604: cur ren -> curren (frequency 9424)
# pair 605: l angu -> langu (frequency 9408)
# pair 606: g g -> gg (frequency 9370)
# pair 607: qu i -> qui (frequency 9360)
# pair 608: pu b -> pub (frequency 9352)
# pair 609: mus li -> musli (frequency 9328)
# pair 610: is h</w> -> ish</w> (frequency 9326)
# pair 611: ic s</w> -> ics</w> (frequency 9323)
# pair 612: an ts</w> -> ants</w> (frequency 9304)
# pair 613: v ed</w> -> ved</w> (frequency 9267)
# pair 614: se x</w> -> sex</w> (frequency 9258)
# pair 615: ali ty</w> -> ality</w> (frequency 9244)
# pair 616: k in -> kin (frequency 9221)
# pair 617: hi gh</w> -> high</w> (frequency 9195)
# pair 618: im port -> import (frequency 9189)
# pair 619: o c -> oc (frequency 9148)
# pair 620: mo vi -> movi (frequency 9108)
# pair 621: s en -> sen (frequency 9104)
# pair 622: re st -> rest (frequency 9074)
# pair 623: sto p</w> -> stop</w> (frequency 9073)
# pair 624: any one</w> -> anyone</w> (frequency 9052)
# pair 625: gir l</w> -> girl</w> (frequency 9037)
# pair 626: is m</w> -> ism</w> (frequency 9036)
# pair 627: li ve</w> -> live</w> (frequency 9014)
# pair 628: i ld</w> -> ild</w> (frequency 8986)
# pair 629: get ting</w> -> getting</w> (frequency 8970)
# pair 630: le g -> leg (frequency 8967)
# pair 631: st ory</w> -> story</w> (frequency 8957)
# pair 632: w ar -> war (frequency 8944)
# pair 633: d on -> don (frequency 8906)
# pair 634: tic al</w> -> tical</w> (frequency 8902)
# pair 635: ac k -> ack (frequency 8882)
# pair 636: n ame</w> -> name</w> (frequency 8871)
# pair 637: to p</w> -> top</w> (frequency 8861)
# pair 638: c er -> cer (frequency 8858)
# pair 639: c s</w> -> cs</w> (frequency 8856)
# pair 640: c y</w> -> cy</w> (frequency 8855)
# pair 641: s al -> sal (frequency 8822)
# pair 642: b e</w> -> be</w> (frequency 8816)
# pair 643: l in -> lin (frequency 8794)
# pair 644: d at -> dat (frequency 8770)
# pair 645: stud ent</w> -> student</w> (frequency 8769)
# pair 646: comp u -> compu (frequency 8725)
# pair 647: bo dy</w> -> body</w> (frequency 8722)
# pair 648: s m -> sm (frequency 8705)
# pair 649: bu y</w> -> buy</w> (frequency 8699)
# pair 650: go ver -> gover (frequency 8697)
# pair 651: l es</w> -> les</w> (frequency 8693)
# pair 652: in s</w> -> ins</w> (frequency 8681)
# pair 653: we b -> web (frequency 8677)
# pair 654: sci ence</w> -> science</w> (frequency 8675)
# pair 655: gen er -> gener (frequency 8675)
# pair 656: h y -> hy (frequency 8674)
# pair 657: tw o</w> -> two</w> (frequency 8672)
# pair 658: v o -> vo (frequency 8595)
# pair 659: pre par -> prepar (frequency 8590)
# pair 660: i a</w> -> ia</w> (frequency 8551)
# pair 661: st ate</w> -> state</w> (frequency 8549)
# pair 662: tri es</w> -> tries</w> (frequency 8541)
# pair 663: c ess</w> -> cess</w> (frequency 8540)
# pair 664: stud y</w> -> study</w> (frequency 8539)
# pair 665: go ing</w> -> going</w> (frequency 8524)
# pair 666: ec ts</w> -> ects</w> (frequency 8521)
# pair 667: il l</w> -> ill</w> (frequency 8517)
# pair 668: i de -> ide (frequency 8515)
# pair 669: ac coun -> accoun (frequency 8468)
# pair 670: re as -> reas (frequency 8454)
# pair 671: l ess</w> -> less</w> (frequency 8451)
# pair 672: h appe -> happe (frequency 8449)
# pair 673: happe n</w> -> happen</w> (frequency 8444)
# pair 674: a tions</w> -> ations</w> (frequency 8430)
# pair 675: l ing</w> -> ling</w> (frequency 8421)
# pair 676: t al -> tal (frequency 8388)
# pair 677: ph ysi -> physi (frequency 8373)
# pair 678: por t</w> -> port</w> (frequency 8326)
# pair 679: h ou -> hou (frequency 8326)
# pair 680: ch o -> cho (frequency 8326)
# pair 681: m m -> mm (frequency 8300)
# pair 682: be li -> beli (frequency 8263)
# pair 683: e u -> eu (frequency 8238)
# pair 684: t ly</w> -> tly</w> (frequency 8228)
# pair 685: gover n -> govern (frequency 8213)
# pair 686: n er</w> -> ner</w> (frequency 8189)
# pair 687: me m -> mem (frequency 8184)
# pair 688: wh ite</w> -> white</w> (frequency 8157)
# pair 689: si de</w> -> side</w> (frequency 8148)
# pair 690: coun tries</w> -> countries</w> (frequency 8144)
# pair 691: st ra -> stra (frequency 8134)
# pair 692: pl ace</w> -> place</w> (frequency 8124)
# pair 693: ste m</w> -> stem</w> (frequency 8104)
# pair 694: en ds</w> -> ends</w> (frequency 8103)
# pair 695: re al</w> -> real</w> (frequency 8088)
# pair 696: chin a</w> -> china</w> (frequency 8048)
# pair 697: b ro -> bro (frequency 8026)
# pair 698: some thing</w> -> something</w> (frequency 8017)
# pair 699: em p -> emp (frequency 7994)
# pair 700: re li -> reli (frequency 7989)
# pair 701: loo k</w> -> look</w> (frequency 7980)
# pair 702: fre e</w> -> free</w> (frequency 7959)
# pair 703: y s</w> -> ys</w> (frequency 7913)
# pair 704: l and</w> -> land</w> (frequency 7906)
# pair 705: re sp -> resp (frequency 7863)
# pair 706: i al</w> -> ial</w> (frequency 7840)
# pair 707: e ve</w> -> eve</w> (frequency 7832)
# pair 708: for m</w> -> form</w> (frequency 7819)
# pair 709: ac h</w> -> ach</w> (frequency 7800)
# pair 710: g er</w> -> ger</w> (frequency 7765)
# pair 711: eng lish</w> -> english</w> (frequency 7754)
# pair 712: in t</w> -> int</w> (frequency 7747)
# pair 713: c lo -> clo (frequency 7734)
# pair 714: he al -> heal (frequency 7730)
# pair 715: b ra -> bra (frequency 7730)
# pair 716: wat er</w> -> water</w> (frequency 7724)
# pair 717: at s</w> -> ats</w> (frequency 7699)
# pair 718: us es</w> -> uses</w> (frequency 7694)
# pair 719: bl ack</w> -> black</w> (frequency 7684)
# pair 720: or t</w> -> ort</w> (frequency 7660)
# pair 721: p op -> pop (frequency 7648)
# pair 722: i d -> id (frequency 7647)
# pair 723: t ec -> tec (frequency 7640)
# pair 724: americ an</w> -> american</w> (frequency 7640)
# pair 725: sy stem</w> -> system</w> (frequency 7628)
# pair 726: rela tion -> relation (frequency 7628)
# pair 727: b en -> ben (frequency 7625)
# pair 728: pa ren -> paren (frequency 7623)
# pair 729: s es</w> -> ses</w> (frequency 7618)
# pair 730: tr ue</w> -> true</w> (frequency 7610)
# pair 731: boo ks</w> -> books</w> (frequency 7602)
# pair 732: pro ble -> proble (frequency 7599)
# pair 733: ap p</w> -> app</w> (frequency 7591)
# pair 734: experi ence</w> -> experience</w> (frequency 7552)
# pair 735: it ed</w> -> ited</w> (frequency 7542)
# pair 736: on om -> onom (frequency 7537)
# pair 737: comp le -> comple (frequency 7534)
# pair 738: r on -> ron (frequency 7512)
# pair 739: ques tions</w> -> questions</w> (frequency 7507)
# pair 740: n at -> nat (frequency 7445)
# pair 741: cl ass</w> -> class</w> (frequency 7445)
# pair 742: is e</w> -> ise</w> (frequency 7441)
# pair 743: pl an -> plan (frequency 7434)
# pair 744: tr ans -> trans (frequency 7426)
# pair 745: an o -> ano (frequency 7418)
# pair 746: w ar</w> -> war</w> (frequency 7413)
# pair 747: p er</w> -> per</w> (frequency 7413)
# pair 748: o ver -> over (frequency 7409)
# pair 749: m e</w> -> me</w> (frequency 7380)
# pair 750: i ght</w> -> ight</w> (frequency 7380)
# pair 751: g ro -> gro (frequency 7364)
# pair 752: num ber</w> -> number</w> (frequency 7347)
# pair 753: govern ment</w> -> government</w> (frequency 7341)
# pair 754: c ap -> cap (frequency 7341)
# pair 755: a k</w> -> ak</w> (frequency 7333)
# pair 756: import ant</w> -> important</w> (frequency 7328)
# pair 757: stud ents</w> -> students</w> (frequency 7324)
# pair 758: ca re -> care (frequency 7315)
# pair 759: ath er</w> -> ather</w> (frequency 7313)
# pair 760: a ir -> air (frequency 7307)
# pair 761: d r -> dr (frequency 7299)
# pair 762: su c -> suc (frequency 7287)
# pair 763: f ol -> fol (frequency 7280)
# pair 764: pl ac -> plac (frequency 7242)
# pair 765: langu age</w> -> language</w> (frequency 7235)
# pair 766: ex t</w> -> ext</w> (frequency 7198)
# pair 767: ch ri -> chri (frequency 7195)
# pair 768: s ing</w> -> sing</w> (frequency 7189)
# pair 769: b a -> ba (frequency 7179)
# pair 770: f ul -> ful (frequency 7167)
# pair 771: c al -> cal (frequency 7149)
# pair 772: d ri -> dri (frequency 7147)
# pair 773: vie w</w> -> view</w> (frequency 7141)
# pair 774: de sig -> desig (frequency 7128)
# pair 775: b a</w> -> ba</w> (frequency 7122)
# pair 776: d ec -> dec (frequency 7117)
# pair 777: m ents</w> -> ments</w> (frequency 7113)
# pair 778: b or -> bor (frequency 7106)
# pair 779: compu ter</w> -> computer</w> (frequency 7089)
# pair 780: t ell</w> -> tell</w> (frequency 7070)
# pair 781: n ed</w> -> ned</w> (frequency 7052)
# pair 782: li c</w> -> lic</w> (frequency 7051)
# pair 783: j ect</w> -> ject</w> (frequency 7049)
# pair 784: r us -> rus (frequency 7024)
# pair 785: at h</w> -> ath</w> (frequency 7008)
# pair 786: in ing</w> -> ining</w> (frequency 6987)
# pair 787: g oo -> goo (frequency 6976)
# pair 788: ou t -> out (frequency 6960)
# pair 789: re ad -> read (frequency 6954)
# pair 790: c ed</w> -> ced</w> (frequency 6949)
# pair 791: su l -> sul (frequency 6930)
# pair 792: pl es</w> -> ples</w> (frequency 6911)
# pair 793: s ed</w> -> sed</w> (frequency 6904)
# pair 794: hu man</w> -> human</w> (frequency 6902)
# pair 795: ke ep</w> -> keep</w> (frequency 6872)
# pair 796: so f -> sof (frequency 6869)
# pair 797: soci al</w> -> social</w> (frequency 6863)
# pair 798: eu ro -> euro (frequency 6854)
# pair 799: as ed</w> -> ased</w> (frequency 6844)
# pair 800: ta in</w> -> tain</w> (frequency 6830)
# pair 801: n on</w> -> non</w> (frequency 6820)
# pair 802: d ra -> dra (frequency 6815)
# pair 803: s ou -> sou (frequency 6781)
# pair 804: ne ver</w> -> never</w> (frequency 6772)
# pair 805: in i -> ini (frequency 6764)
# pair 806: on al</w> -> onal</w> (frequency 6763)
# pair 807: gir ls</w> -> girls</w> (frequency 6758)
# pair 808: g y</w> -> gy</w> (frequency 6757)
# pair 809: ti v -> tiv (frequency 6756)
# pair 810: gh ts</w> -> ghts</w> (frequency 6754)
# pair 811: se ar -> sear (frequency 6752)
# pair 812: w a -> wa (frequency 6751)
# pair 813: al ways</w> -> always</w> (frequency 6738)
# pair 814: n ec -> nec (frequency 6736)
# pair 815: sti tu -> stitu (frequency 6733)
# pair 816: man ag -> manag (frequency 6702)
# pair 817: wor king</w> -> working</w> (frequency 6697)
# pair 818: ever y</w> -> every</w> (frequency 6691)
# pair 819: ai d</w> -> aid</w> (frequency 6678)
# pair 820: o s</w> -> os</w> (frequency 6676)
# pair 821: p e</w> -> pe</w> (frequency 6658)
# pair 822: i ly</w> -> ily</w> (frequency 6657)
# pair 823: an im -> anim (frequency 6654)
# pair 824: c el -> cel (frequency 6637)
# pair 825: vi de -> vide (frequency 6617)
# pair 826: mal e</w> -> male</w> (frequency 6612)
# pair 827: s on</w> -> son</w> (frequency 6608)
# pair 828: h i</w> -> hi</w> (frequency 6599)
# pair 829: p ing</w> -> ping</w> (frequency 6592)
# pair 830: ac tu -> actu (frequency 6586)
# pair 831: ec onom -> econom (frequency 6581)
# pair 832: pre sid -> presid (frequency 6564)
# pair 833: char ac -> charac (frequency 6563)
# pair 834: v en</w> -> ven</w> (frequency 6561)
# pair 835: po si -> posi (frequency 6557)
# pair 836: m al</w> -> mal</w> (frequency 6555)
# pair 837: h ome</w> -> home</w> (frequency 6554)
# pair 838: fri ends</w> -> friends</w> (frequency 6546)
# pair 839: sp eci -> speci (frequency 6537)
# pair 840: ch il -> chil (frequency 6533)
# pair 841: sof tw -> softw (frequency 6525)
# pair 842: str uc -> struc (frequency 6522)
# pair 843: care er</w> -> career</w> (frequency 6514)
# pair 844: in st -> inst (frequency 6512)
# pair 845: dat a</w> -> data</w> (frequency 6489)
# pair 846: st er -> ster (frequency 6487)
# pair 847: f ore -> fore (frequency 6450)
# pair 848: h a -> ha (frequency 6449)
# pair 849: c en -> cen (frequency 6437)
# pair 850: b lo -> blo (frequency 6434)
# pair 851: p sy -> psy (frequency 6405)
# pair 852: d ays</w> -> days</w> (frequency 6397)
# pair 853: na tional</w> -> national</w> (frequency 6391)
# pair 854: chin ese</w> -> chinese</w> (frequency 6374)
# pair 855: relation ship</w> -> relationship</w> (frequency 6372)
# pair 856: t ors</w> -> tors</w> (frequency 6364)
# pair 857: gra du -> gradu (frequency 6361)
# pair 858: inter n -> intern (frequency 6356)
# pair 859: st a -> sta (frequency 6355)
# pair 860: mo ve</w> -> move</w> (frequency 6352)
# pair 861: at e -> ate (frequency 6314)
# pair 862: americ a</w> -> america</w> (frequency 6305)
# pair 863: st ri -> stri (frequency 6299)
# pair 864: d one</w> -> done</w> (frequency 6291)
# pair 865: t ers</w> -> ters</w> (frequency 6290)
# pair 866: te m -> tem (frequency 6288)
# pair 867: gra ph -> graph (frequency 6288)
# pair 868: mar ri -> marri (frequency 6286)
# pair 869: w ing</w> -> wing</w> (frequency 6282)
# pair 870: ar m -> arm (frequency 6280)
# pair 871: k i -> ki (frequency 6270)
# pair 872: wri te</w> -> write</w> (frequency 6269)
# pair 873: rus si -> russi (frequency 6231)
# pair 874: ar t</w> -> art</w> (frequency 6231)
# pair 875: pop u -> popu (frequency 6226)
# pair 876: or der</w> -> order</w> (frequency 6208)
# pair 877: softw are</w> -> software</w> (frequency 6201)
# pair 878: go t</w> -> got</w> (frequency 6179)
# pair 879: d i</w> -> di</w> (frequency 6170)
# pair 880: d ate</w> -> date</w> (frequency 6167)
# pair 881: cont ro -> contro (frequency 6154)
# pair 882: g es</w> -> ges</w> (frequency 6151)
# pair 883: li ght</w> -> light</w> (frequency 6141)
# pair 884: t est</w> -> test</w> (frequency 6121)
# pair 885: fu ture</w> -> future</w> (frequency 6121)
# pair 886: str y</w> -> stry</w> (frequency 6113)
# pair 887: or i -> ori (frequency 6105)
# pair 888: ad a</w> -> ada</w> (frequency 6100)
# pair 889: s c</w> -> sc</w> (frequency 6093)
# pair 890: as h -> ash (frequency 6090)
# pair 891: pro f -> prof (frequency 6086)
# pair 892: reli gi -> religi (frequency 6085)
# pair 893: ch em -> chem (frequency 6081)
# pair 894: paren ts</w> -> parents</w> (frequency 6078)
# pair 895: am es</w> -> ames</w> (frequency 6070)
# pair 896: as k</w> -> ask</w> (frequency 6069)
# pair 897: ben e -> bene (frequency 6061)
# pair 898: m il -> mil (frequency 6055)
# pair 899: ir e</w> -> ire</w> (frequency 6053)
# pair 900: tr ac -> trac (frequency 6050)
# pair 901: m ul -> mul (frequency 6034)
# pair 902: ex am</w> -> exam</w> (frequency 6025)
# pair 903: u al</w> -> ual</w> (frequency 6017)
# pair 904: lear ning</w> -> learning</w> (frequency 6014)
# pair 905: pro ve</w> -> prove</w> (frequency 6010)
# pair 906: je e</w> -> jee</w> (frequency 6000)
# pair 907: in cre -> incre (frequency 5997)
# pair 908: de red</w> -> dered</w> (frequency 5993)
# pair 909: m or -> mor (frequency 5989)
# pair 910: s ex -> sex (frequency 5980)
# pair 911: c a</w> -> ca</w> (frequency 5980)
# pair 912: accoun t</w> -> account</w> (frequency 5978)
# pair 913: cour se</w> -> course</w> (frequency 5977)
# pair 914: th er -> ther (frequency 5964)
# pair 915: st ing</w> -> sting</w> (frequency 5960)
# pair 916: fam ily</w> -> family</w> (frequency 5956)
# pair 917: la tion</w> -> lation</w> (frequency 5953)
# pair 918: w in -> win (frequency 5952)
# pair 919: f ood</w> -> food</w> (frequency 5952)
# pair 920: on d</w> -> ond</w> (frequency 5945)
# pair 921: w n -> wn (frequency 5943)
# pair 922: de gre -> degre (frequency 5936)
# pair 923: web site</w> -> website</w> (frequency 5935)
# pair 924: po wer</w> -> power</w> (frequency 5932)
# pair 925: a ma -> ama (frequency 5921)
# pair 926: st re -> stre (frequency 5916)
# pair 927: c ar</w> -> car</w> (frequency 5915)
# pair 928: c ra -> cra (frequency 5910)
# pair 929: gu y</w> -> guy</w> (frequency 5900)
# pair 930: kin d</w> -> kind</w> (frequency 5895)
# pair 931: an i -> ani (frequency 5887)
# pair 932: si ve</w> -> sive</w> (frequency 5882)
# pair 933: ul t</w> -> ult</w> (frequency 5878)
# pair 934: re ad</w> -> read</w> (frequency 5878)
# pair 935: lo t</w> -> lot</w> (frequency 5876)
# pair 936: w r -> wr (frequency 5875)
# pair 937: w ell</w> -> well</w> (frequency 5865)
# pair 938: re qui -> requi (frequency 5854)
# pair 939: ano ther</w> -> another</w> (frequency 5849)
# pair 940: k ist -> kist (frequency 5847)
# pair 941: tech no -> techno (frequency 5828)
# pair 942: c ess -> cess (frequency 5822)
# pair 943: t o</w> -> to</w> (frequency 5815)
# pair 944: s m</w> -> sm</w> (frequency 5815)
# pair 945: k en</w> -> ken</w> (frequency 5801)
# pair 946: comm un -> commun (frequency 5782)
# pair 947: leg al</w> -> legal</w> (frequency 5781)
# pair 948: do c -> doc (frequency 5781)
# pair 949: us a</w> -> usa</w> (frequency 5765)
# pair 950: bi o -> bio (frequency 5765)
# pair 951: st ates</w> -> states</w> (frequency 5759)
# pair 952: p le -> ple (frequency 5755)
# pair 953: sear ch</w> -> search</w> (frequency 5753)
# pair 954: mu si -> musi (frequency 5751)
# pair 955: r ac -> rac (frequency 5748)
# pair 956: ar ound</w> -> around</w> (frequency 5740)
# pair 957: we e -> wee (frequency 5725)
# pair 958: pa kist -> pakist (frequency 5723)
# pair 959: f av -> fav (frequency 5722)
# pair 960: li ber -> liber (frequency 5721)
# pair 961: beli eve</w> -> believe</w> (frequency 5712)
# pair 962: vi si -> visi (frequency 5698)
# pair 963: goo gle</w> -> google</w> (frequency 5698)
# pair 964: m en -> men (frequency 5681)
# pair 965: f il -> fil (frequency 5681)
# pair 966: v is -> vis (frequency 5678)
# pair 967: p ic -> pic (frequency 5677)
# pair 968: al s -> als (frequency 5676)
# pair 969: tim es</w> -> times</w> (frequency 5669)
# pair 970: ph o -> pho (frequency 5665)
# pair 971: or g -> org (frequency 5661)
# pair 972: s our -> sour (frequency 5645)
# pair 973: happ ens</w> -> happens</w> (frequency 5638)
# pair 974: se e -> see (frequency 5621)
# pair 975: hi gh -> high (frequency 5612)
# pair 976: in ste -> inste (frequency 5596)
# pair 977: f er</w> -> fer</w> (frequency 5588)
# pair 978: n ess</w> -> ness</w> (frequency 5579)
# pair 979: wr ong</w> -> wrong</w> (frequency 5577)
# pair 980: bi g</w> -> big</w> (frequency 5576)
# pair 981: e duc -> educ (frequency 5557)
# pair 982: wor d</w> -> word</w> (frequency 5540)
# pair 983: le t</w> -> let</w> (frequency 5538)
# pair 984: t om -> tom (frequency 5525)
# pair 985: c le -> cle (frequency 5521)
# pair 986: d d -> dd (frequency 5515)
# pair 987: fl u -> flu (frequency 5501)
# pair 988: l y -> ly (frequency 5496)
# pair 989: compan ies</w> -> companies</w> (frequency 5494)
# pair 990: fac e</w> -> face</w> (frequency 5484)
# pair 991: to day</w> -> today</w> (frequency 5480)
# pair 992: on es</w> -> ones</w> (frequency 5477)
# pair 993: typ e</w> -> type</w> (frequency 5470)
# pair 994: h ard</w> -> hard</w> (frequency 5470)
# pair 995: d ro -> dro (frequency 5469)
# pair 996: st and</w> -> stand</w> (frequency 5461)
# pair 997: et y</w> -> ety</w> (frequency 5452)
# pair 998: sho w</w> -> show</w> (frequency 5448)
# pair 999: ic es</w> -> ices</w> (frequency 5431)
# pair 1000: ma jo -> majo (frequency 5427)
# pair 1001: americ ans</w> -> americans</w> (frequency 5427)
# pair 1002: ma kes</w> -> makes</w> (frequency 5414)
# pair 1003: wom an</w> -> woman</w> (frequency 5408)
# pair 1004: movi e</w> -> movie</w> (frequency 5402)
# pair 1005: majo r</w> -> major</w> (frequency 5402)
# pair 1006: hi story</w> -> history</w> (frequency 5399)
# pair 1007: di c -> dic (frequency 5386)
# pair 1008: als o</w> -> also</w> (frequency 5383)
# pair 1009: di ff -> diff (frequency 5369)
# pair 1010: j ap -> jap (frequency 5360)
# pair 1011: h ate</w> -> hate</w> (frequency 5360)
# pair 1012: l ast</w> -> last</w> (frequency 5352)
# pair 1013: emp lo -> emplo (frequency 5341)
# pair 1014: go d</w> -> god</w> (frequency 5339)
# pair 1015: can ada</w> -> canada</w> (frequency 5328)
# pair 1016: progra mm -> programm (frequency 5306)
# pair 1017: p ay</w> -> pay</w> (frequency 5305)
# pair 1018: ques tion</w> -> question</w> (frequency 5296)
# pair 1019: b ab -> bab (frequency 5296)
# pair 1020: ma in</w> -> main</w> (frequency 5284)
# pair 1021: c all -> call (frequency 5284)
# pair 1022: nor mal</w> -> normal</w> (frequency 5277)
# pair 1023: ist s</w> -> ists</w> (frequency 5277)
# pair 1024: st u -> stu (frequency 5275)
# pair 1025: it al</w> -> ital</w> (frequency 5271)
# pair 1026: t el -> tel (frequency 5259)
# pair 1027: a re -> are (frequency 5253)
# pair 1028: v ol -> vol (frequency 5237)
# pair 1029: th s</w> -> ths</w> (frequency 5233)
# pair 1030: musli ms</w> -> muslims</w> (frequency 5231)
# pair 1031: ch ild</w> -> child</w> (frequency 5231)
# pair 1032: kno wn</w> -> known</w> (frequency 5229)
# pair 1033: t op -> top (frequency 5224)
# pair 1034: u tion</w> -> ution</w> (frequency 5223)
# pair 1035: ran k</w> -> rank</w> (frequency 5221)
# pair 1036: gr ou -> grou (frequency 5219)
# pair 1037: n ar -> nar (frequency 5211)
# pair 1038: de mo -> demo (frequency 5211)
# pair 1039: c is -> cis (frequency 5210)
# pair 1040: co st</w> -> cost</w> (frequency 5205)
# pair 1041: presid ent</w> -> president</w> (frequency 5192)
# pair 1042: ec tive</w> -> ective</w> (frequency 5190)
# pair 1043: cre ate</w> -> create</w> (frequency 5181)
# pair 1044: li ving</w> -> living</w> (frequency 5174)
# pair 1045: ac ce -> acce (frequency 5174)
# pair 1046: et ing</w> -> eting</w> (frequency 5172)
# pair 1047: mi t</w> -> mit</w> (frequency 5169)
# pair 1048: pla y</w> -> play</w> (frequency 5162)
# pair 1049: chil dre -> childre (frequency 5154)
# pair 1050: hu man -> human (frequency 5148)
# pair 1051: childre n</w> -> children</w> (frequency 5148)
# pair 1052: ic i -> ici (frequency 5147)
# pair 1053: fac e -> face (frequency 5147)
# pair 1054: in ve -> inve (frequency 5141)
# pair 1055: degre e</w> -> degree</w> (frequency 5141)
# pair 1056: ci vi -> civi (frequency 5140)
# pair 1057: fi el -> fiel (frequency 5135)
# pair 1058: ou gh</w> -> ough</w> (frequency 5134)
# pair 1059: g n -> gn (frequency 5132)
# pair 1060: m p -> mp (frequency 5119)
# pair 1061: hou se</w> -> house</w> (frequency 5118)
# pair 1062: g ar -> gar (frequency 5118)
# pair 1063: ro o -> roo (frequency 5110)
# pair 1064: c ity</w> -> city</w> (frequency 5110)
# pair 1065: in f -> inf (frequency 5105)
# pair 1066: consi dered</w> -> considered</w> (frequency 5103)
# pair 1067: t en</w> -> ten</w> (frequency 5096)
# pair 1068: pu t</w> -> put</w> (frequency 5091)
# pair 1069: ver age</w> -> verage</w> (frequency 5088)
# pair 1070: par t</w> -> part</w> (frequency 5088)
# pair 1071: d ge</w> -> dge</w> (frequency 5086)
# pair 1072: pro vi -> provi (frequency 5079)
# pair 1073: l ed</w> -> led</w> (frequency 5068)
# ...
# pair 9639: ca ine</w> -> caine</w> (frequency 234)
# pair 9640: as ka</w> -> aska</w> (frequency 234)
# pair 9641: ariz ona</w> -> arizona</w> (frequency 234)
# pair 9642: ap oc -> apoc (frequency 234)
# pair 9643: accomp lish</w> -> accomplish</w> (frequency 234)
# pair 9644: wid th</w> -> width</w> (frequency 233)
# pair 9645: vir al</w> -> viral</w> (frequency 233)
# pair 9646: thre ats</w> -> threats</w> (frequency 233)
# pair 9647: thap ar</w> -> thapar</w> (frequency 233)
# pair 9648: super power</w> -> superpower</w> (frequency 233)
# pair 9649: sk ir -> skir (frequency 233)
# pair 9650: shi p -> ship (frequency 233)
# pair 9651: sha h</w> -> shah</w> (frequency 233)
# pair 9652: scri pts</w> -> scripts</w> (frequency 233)
# pair 9653: ro ck -> rock (frequency 233)
# pair 9654: ra bies</w> -> rabies</w> (frequency 233)
# pair 9655: out door</w> -> outdoor</w> (frequency 233)
# pair 9656: nik on</w> -> nikon</w> (frequency 233)
# pair 9657: n ri</w> -> nri</w> (frequency 233)
# pair 9658: m h -> mh (frequency 233)
# pair 9659: int ended</w> -> intended</w> (frequency 233)
# pair 9660: fle xi -> flexi (frequency 233)
# pair 9661: commer ci -> commerci (frequency 233)
# pair 9662: clin ic</w> -> clinic</w> (frequency 233)
# pair 9663: ch ill</w> -> chill</w> (frequency 233)
# pair 9664: billi onaire</w> -> billionaire</w> (frequency 233)
# pair 9665: be e</w> -> bee</w> (frequency 233)
# pair 9666: au tical</w> -> autical</w> (frequency 233)
# pair 9667: asp iring</w> -> aspiring</w> (frequency 233)
# pair 9668: ad ju -> adju (frequency 233)
# pair 9669: vic tory</w> -> victory</w> (frequency 232)
# pair 9670: v l -> vl (frequency 232)
# pair 9671: v able</w> -> vable</w> (frequency 232)
# pair 9672: tri gger</w> -> trigger</w> (frequency 232)
# pair 9673: skin ned</w> -> skinned</w> (frequency 232)
# pair 9674: sc am -> scam (frequency 232)
# pair 9675: s essions</w> -> sessions</w> (frequency 232)
# pair 9676: refl ect</w> -> reflect</w> (frequency 232)
# pair 9677: pu ber -> puber (frequency 232)
# pair 9678: in her -> inher (frequency 232)
# pair 9679: id ers</w> -> iders</w> (frequency 232)
# pair 9680: hou ston</w> -> houston</w> (frequency 232)
# pair 9681: gi e</w> -> gie</w> (frequency 232)
# pair 9682: famili ar</w> -> familiar</w> (frequency 232)
# pair 9683: ex cess</w> -> excess</w> (frequency 232)
# pair 9684: bra tion</w> -> bration</w> (frequency 232)
# pair 9685: apologi ze</w> -> apologize</w> (frequency 232)
# pair 9686: adap t</w> -> adapt</w> (frequency 232)
# pair 9687: y land</w> -> yland</w> (frequency 231)
# pair 9688: won dering</w> -> wondering</w> (frequency 231)
# pair 9689: w i</w> -> wi</w> (frequency 231)
# pair 9690: tom y</w> -> tomy</w> (frequency 231)
# pair 9691: restric tions</w> -> restrictions</w> (frequency 231)
# pair 9692: repe atedly</w> -> repeatedly</w> (frequency 231)
# pair 9693: refriger ator</w> -> refrigerator</w> (frequency 231)
# pair 9694: re ar</w> -> rear</w> (frequency 231)
# pair 9695: promin ent</w> -> prominent</w> (frequency 231)
# pair 9696: ohi o</w> -> ohio</w> (frequency 231)
# pair 9697: man n</w> -> mann</w> (frequency 231)
# pair 9698: fer tili -> fertili (frequency 231)
# pair 9699: ec ution</w> -> ecution</w> (frequency 231)
# pair 9700: diam eter</w> -> diameter</w> (frequency 231)
# pair 9701: con sen -> consen (frequency 231)
# pair 9702: con firm</w> -> confirm</w> (frequency 231)
# pair 9703: chec ked</w> -> checked</w> (frequency 231)
# pair 9704: busin ess -> business (frequency 231)
# pair 9705: behavi oral</w> -> behavioral</w> (frequency 231)
# pair 9706: astronau ts</w> -> astronauts</w> (frequency 231)
# pair 9707: asse mble</w> -> assemble</w> (frequency 231)
# pair 9708: apoc alyp -> apocalyp (frequency 231)
# pair 9709: wei ghts</w> -> weights</w> (frequency 230)
# pair 9710: w ron -> wron (frequency 230)
# pair 9711: w ishes</w> -> wishes</w> (frequency 230)
# pair 9712: w ich</w> -> wich</w> (frequency 230)
# pair 9713: vish nu</w> -> vishnu</w> (frequency 230)
# pair 9714: vis u -> visu (frequency 230)
# pair 9715: sp am</w> -> spam</w> (frequency 230)
# pair 9716: re mains</w> -> remains</w> (frequency 230)
# pair 9717: r ough</w> -> rough</w> (frequency 230)
# pair 9718: pharmaceu tical</w> -> pharmaceutical</w> (frequency 230)
# pair 9719: paint ings</w> -> paintings</w> (frequency 230)
# pair 9720: li ghter</w> -> lighter</w> (frequency 230)
# pair 9721: ill umin -> illumin (frequency 230)
# pair 9722: for mu -> formu (frequency 230)
# pair 9723: d red</w> -> dred</w> (frequency 230)
# pair 9724: comp aring</w> -> comparing</w> (frequency 230)
# pair 9725: bul l -> bull (frequency 230)
# pair 9726: activ ated</w> -> activated</w> (frequency 230)
# pair 9727: vi br -> vibr (frequency 229)
# pair 9728: stri c -> stric (frequency 229)
# pair 9729: sing ers</w> -> singers</w> (frequency 229)
# pair 9730: scienti fically</w> -> scientifically</w> (frequency 229)
# pair 9731: represen tation</w> -> representation</w> (frequency 229)
# pair 9732: read er</w> -> reader</w> (frequency 229)
# pair 9733: ra ma</w> -> rama</w> (frequency 229)
# pair 9734: r hy -> rhy (frequency 229)
# pair 9735: puber ty</w> -> puberty</w> (frequency 229)
# pair 9736: pl ing</w> -> pling</w> (frequency 229)
# pair 9737: person alities</w> -> personalities</w> (frequency 229)
# pair 9738: moun tains</w> -> mountains</w> (frequency 229)
# pair 9739: motiv ational</w> -> motivational</w> (frequency 229)
# pair 9740: mo le -> mole (frequency 229)
# pair 9741: manufac ture</w> -> manufacture</w> (frequency 229)
# pair 9742: kis sing</w> -> kissing</w> (frequency 229)
# pair 9743: inv o -> invo (frequency 229)
# pair 9744: hon or</w> -> honor</w> (frequency 229)
# pair 9745: haw king</w> -> hawking</w> (frequency 229)
# pair 9746: g rid</w> -> grid</w> (frequency 229)
# pair 9747: for gotten</w> -> forgotten</w> (frequency 229)
# pair 9748: dro ps</w> -> drops</w> (frequency 229)
# pair 9749: credi ts</w> -> credits</w> (frequency 229)
# pair 9750: cra mps</w> -> cramps</w> (frequency 229)
# pair 9751: carol ina</w> -> carolina</w> (frequency 229)
# pair 9752: calori e</w> -> calorie</w> (frequency 229)
# pair 9753: ban ning</w> -> banning</w> (frequency 229)
# pair 9754: b com</w> -> bcom</w> (frequency 229)
# pair 9755: ar ray</w> -> array</w> (frequency 229)
# pair 9756: anatom y</w> -> anatomy</w> (frequency 229)
# pair 9757: y an -> yan (frequency 228)
# pair 9758: wh at</w> -> what</w> (frequency 228)
# pair 9759: up dated</w> -> updated</w> (frequency 228)
# pair 9760: ul l</w> -> ull</w> (frequency 228)
# pair 9761: tw ins</w> -> twins</w> (frequency 228)
# pair 9762: tr uc -> truc (frequency 228)
# pair 9763: sun day</w> -> sunday</w> (frequency 228)
# pair 9764: spo tify</w> -> spotify</w> (frequency 228)
# pair 9765: si ck -> sick (frequency 228)
# pair 9766: sco tt</w> -> scott</w> (frequency 228)
# pair 9767: po les</w> -> poles</w> (frequency 228)
# pair 9768: ou l</w> -> oul</w> (frequency 228)
# pair 9769: olymp ics</w> -> olympics</w> (frequency 228)
# pair 9770: mo tors</w> -> motors</w> (frequency 228)
# pair 9771: is ation</w> -> isation</w> (frequency 228)
# pair 9772: interpre tation</w> -> interpretation</w> (frequency 228)
# pair 9773: iden tical</w> -> identical</w> (frequency 228)
# pair 9774: hab ad</w> -> habad</w> (frequency 228)
# pair 9775: fail ures</w> -> failures</w> (frequency 228)
# pair 9776: end ers</w> -> enders</w> (frequency 228)
# pair 9777: ear ned</w> -> earned</w> (frequency 228)
# pair 9778: dist urb -> disturb (frequency 228)
# pair 9779: diplom atic</w> -> diplomatic</w> (frequency 228)
# pair 9780: des perate</w> -> desperate</w> (frequency 228)
# pair 9781: delo it -> deloit (frequency 228)
# pair 9782: coo ling</w> -> cooling</w> (frequency 228)
# pair 9783: col om -> colom (frequency 228)
# pair 9784: cin ema</w> -> cinema</w> (frequency 228)
# pair 9785: bu re -> bure (frequency 228)
# pair 9786: ar mor</w> -> armor</w> (frequency 228)
# pair 9787: an ni -> anni (frequency 228)
# pair 9788: ak ash</w> -> akash</w> (frequency 228)
# pair 9789: visi ons</w> -> visions</w> (frequency 227)
# pair 9790: su ffered</w> -> suffered</w> (frequency 227)
# pair 9791: re min -> remin (frequency 227)
# pair 9792: p ics</w> -> pics</w> (frequency 227)
# pair 9793: p ath -> path (frequency 227)
# pair 9794: op position</w> -> opposition</w> (frequency 227)
# pair 9795: op pon -> oppon (frequency 227)
# pair 9796: ni ke</w> -> nike</w> (frequency 227)
# pair 9797: nag ar</w> -> nagar</w> (frequency 227)
# pair 9798: li te</w> -> lite</w> (frequency 227)
# pair 9799: k il -> kil (frequency 227)
# pair 9800: je ff</w> -> jeff</w> (frequency 227)
# pair 9801: histor ically</w> -> historically</w> (frequency 227)
# pair 9802: he ated</w> -> heated</w> (frequency 227)
# pair 9803: fir ing</w> -> firing</w> (frequency 227)
# pair 9804: f ing</w> -> fing</w> (frequency 227)
# pair 9805: elem entary</w> -> elementary</w> (frequency 227)
# pair 9806: deloit te</w> -> deloitte</w> (frequency 227)
# pair 9807: contro ls</w> -> controls</w> (frequency 227)
# pair 9808: char ity</w> -> charity</w> (frequency 227)
# pair 9809: bom bs</w> -> bombs</w> (frequency 227)
# pair 9810: ac ids</w> -> acids</w> (frequency 227)
# pair 9811: un happy</w> -> unhappy</w> (frequency 226)
# pair 9812: the ists</w> -> theists</w> (frequency 226)
# pair 9813: smar test</w> -> smartest</w> (frequency 226)
# pair 9814: s am</w> -> sam</w> (frequency 226)
# pair 9815: rom ans</w> -> romans</w> (frequency 226)
# pair 9816: ro m</w> -> rom</w> (frequency 226)
# pair 9817: re feren -> referen (frequency 226)
# pair 9818: push ing</w> -> pushing</w> (frequency 226)
# pair 9819: prof iles</w> -> profiles</w> (frequency 226)
# pair 9820: prison ers</w> -> prisoners</w> (frequency 226)
# pair 9821: pot entially</w> -> potentially</w> (frequency 226)
# pair 9822: pho sp -> phosp (frequency 226)
# pair 9823: pan els</w> -> panels</w> (frequency 226)
# pair 9824: pal m</w> -> palm</w> (frequency 226)
# pair 9825: o cr -> ocr (frequency 226)
# pair 9826: mas cul -> mascul (frequency 226)
# pair 9827: lic k</w> -> lick</w> (frequency 226)
# pair 9828: it unes</w> -> itunes</w> (frequency 226)
# pair 9829: honest ly</w> -> honestly</w> (frequency 226)
# pair 9830: he tic</w> -> hetic</w> (frequency 226)
# pair 9831: gro ss</w> -> gross</w> (frequency 226)
# pair 9832: enti ty</w> -> entity</w> (frequency 226)
# pair 9833: end o</w> -> endo</w> (frequency 226)
# pair 9834: encoun tered</w> -> encountered</w> (frequency 226)
# pair 9835: di alo -> dialo (frequency 226)
# pair 9836: de t -> det (frequency 226)
# pair 9837: d ges</w> -> dges</w> (frequency 226)
# pair 9838: connec ting</w> -> connecting</w> (frequency 226)
# pair 9839: competi tors</w> -> competitors</w> (frequency 226)
# pair 9840: auth or -> author (frequency 226)
# pair 9841: as us</w> -> asus</w> (frequency 226)
# pair 9842: approxim ately</w> -> approximately</w> (frequency 226)
# pair 9843: app ing</w> -> apping</w> (frequency 226)
# pair 9844: an ch -> anch (frequency 226)
# pair 9845: al ties</w> -> alties</w> (frequency 226)
# pair 9846: z ant</w> -> zant</w> (frequency 225)
# pair 9847: war ts</w> -> warts</w> (frequency 225)
# pair 9848: w all -> wall (frequency 225)
# pair 9849: un less</w> -> unless</w> (frequency 225)
# pair 9850: ul tr -> ultr (frequency 225)
# pair 9851: too th -> tooth (frequency 225)
# pair 9852: sho w -> show (frequency 225)
# pair 9853: sha ve</w> -> shave</w> (frequency 225)
# pair 9854: ru ined</w> -> ruined</w> (frequency 225)
# pair 9855: pus sy</w> -> pussy</w> (frequency 225)
# pair 9856: produc er</w> -> producer</w> (frequency 225)
# pair 9857: pe ti -> peti (frequency 225)
# pair 9858: pe ar -> pear (frequency 225)
# pair 9859: origin ally</w> -> originally</w> (frequency 225)
# pair 9860: n ano -> nano (frequency 225)
# pair 9861: mit ting</w> -> mitting</w> (frequency 225)
# pair 9862: mc donald</w> -> mcdonald</w> (frequency 225)
# pair 9863: m us</w> -> mus</w> (frequency 225)
# pair 9864: ll c</w> -> llc</w> (frequency 225)
# pair 9865: lic ation</w> -> lication</w> (frequency 225)
# pair 9866: libr aries</w> -> libraries</w> (frequency 225)
# pair 9867: li zed</w> -> lized</w> (frequency 225)
# pair 9868: hypothe tically</w> -> hypothetically</w> (frequency 225)
# pair 9869: gr in -> grin (frequency 225)
# pair 9870: experim ents</w> -> experiments</w> (frequency 225)
# pair 9871: dra s</w> -> dras</w> (frequency 225)
# pair 9872: del ta</w> -> delta</w> (frequency 225)
# pair 9873: cu ps</w> -> cups</w> (frequency 225)
# pair 9874: continu ed</w> -> continued</w> (frequency 225)
# pair 9875: consum ing</w> -> consuming</w> (frequency 225)
# pair 9876: collap sed</w> -> collapsed</w> (frequency 225)
# pair 9877: b ou -> bou (frequency 225)
# pair 9878: ar du -> ardu (frequency 225)
# pair 9879: and ru -> andru (frequency 225)
# pair 9880: am mon -> ammon (frequency 225)
# pair 9881: aer on -> aeron (frequency 225)
# pair 9882: a zer -> azer (frequency 225)
# pair 9883: ten nes -> tennes (frequency 224)
# pair 9884: tel angana</w> -> telangana</w> (frequency 224)
# pair 9885: tal ented</w> -> talented</w> (frequency 224)
# pair 9886: sym bio -> symbio (frequency 224)
# pair 9887: scor pi -> scorpi (frequency 224)
# pair 9888: pop e</w> -> pope</w> (frequency 224)
# pair 9889: po orly</w> -> poorly</w> (frequency 224)
# pair 9890: pass es</w> -> passes</w> (frequency 224)
# pair 9891: no bel</w> -> nobel</w> (frequency 224)
# pair 9892: n es</w> -> nes</w> (frequency 224)
# pair 9893: molecu le</w> -> molecule</w> (frequency 224)
# pair 9894: men tality</w> -> mentality</w> (frequency 224)
# pair 9895: manufactu rer</w> -> manufacturer</w> (frequency 224)
# pair 9896: magaz ines</w> -> magazines</w> (frequency 224)
# pair 9897: intro verts</w> -> introverts</w> (frequency 224)
# pair 9898: inter nationally</w> -> internationally</w> (frequency 224)
# pair 9899: ic ker</w> -> icker</w> (frequency 224)
# pair 9900: hypothe tical</w> -> hypothetical</w> (frequency 224)
# pair 9901: fli p</w> -> flip</w> (frequency 224)
# pair 9902: fa ils</w> -> fails</w> (frequency 224)
# pair 9903: expi red</w> -> expired</w> (frequency 224)
# pair 9904: el led</w> -> elled</w> (frequency 224)
# pair 9905: de v</w> -> dev</w> (frequency 224)
# pair 9906: cr ush -> crush (frequency 224)
# pair 9907: cr acking</w> -> cracking</w> (frequency 224)
# pair 9908: con feder -> confeder (frequency 224)
# pair 9909: bhu ban -> bhuban (frequency 224)
# pair 9910: ali zing</w> -> alizing</w> (frequency 224)
# pair 9911: ad i</w> -> adi</w> (frequency 224)
# pair 9912: actre sses</w> -> actresses</w> (frequency 224)
# pair 9913: weak ness</w> -> weakness</w> (frequency 223)
# pair 9914: vac ations</w> -> vacations</w> (frequency 223)
# pair 9915: ti me -> time (frequency 223)
# pair 9916: synthe tic</w> -> synthetic</w> (frequency 223)
# pair 9917: st ated</w> -> stated</w> (frequency 223)
# pair 9918: soun d -> sound (frequency 223)
# pair 9919: sle pt</w> -> slept</w> (frequency 223)
# pair 9920: sc ars</w> -> scars</w> (frequency 223)
# pair 9921: ro y</w> -> roy</w> (frequency 223)
# pair 9922: repu ted</w> -> reputed</w> (frequency 223)
# pair 9923: r ounds</w> -> rounds</w> (frequency 223)
# pair 9924: physi cist</w> -> physicist</w> (frequency 223)
# pair 9925: over night</w> -> overnight</w> (frequency 223)
# pair 9926: medic ines</w> -> medicines</w> (frequency 223)
# pair 9927: manip ulate</w> -> manipulate</w> (frequency 223)
# pair 9928: i o</w> -> io</w> (frequency 223)
# pair 9929: eng aged</w> -> engaged</w> (frequency 223)
# pair 9930: en cryp -> encryp (frequency 223)
# pair 9931: e fl</w> -> efl</w> (frequency 223)
# pair 9932: e don -> edon (frequency 223)
# pair 9933: de press -> depress (frequency 223)
# pair 9934: corpor ations</w> -> corporations</w> (frequency 223)
# pair 9935: compre h -> compreh (frequency 223)
# pair 9936: c pt</w> -> cpt</w> (frequency 223)
# pair 9937: bhuban es -> bhubanes (frequency 223)
# pair 9938: ash ed</w> -> ashed</w> (frequency 223)
# pair 9939: alla habad</w> -> allahabad</w> (frequency 223)
# pair 9940: v p</w> -> vp</w> (frequency 222)
# pair 9941: trac ks</w> -> tracks</w> (frequency 222)
# pair 9942: tra u -> trau (frequency 222)
# pair 9943: text books</w> -> textbooks</w> (frequency 222)
# pair 9944: supple ment</w> -> supplement</w> (frequency 222)
# pair 9945: sm oo -> smoo (frequency 222)
# pair 9946: reson ance</w> -> resonance</w> (frequency 222)
# pair 9947: r r -> rr (frequency 222)

# %% [markdown]
# Now we replace words in out **notes** with corresponding subwords and save them all as one text file called **corpus**. In a next step we use **corpus** to train glove embeddings.

# %%
CORPUS_OUTPUT_PATH = os.path.join(DATA_PATH, 'glove', 'corpus.txt')

# %%
from subword_nmt import apply_bpe
from subword_nmt.apply_bpe import read_vocabulary

# %%
#minimum frequency of particular subword to be used.
vocab_threshold = None

with open(VOCAB_PATH, encoding='utf-8') as vocab_file:
    vocab = read_vocabulary(vocab_file, threshold=vocab_threshold)
        
with open(CODES_PATH, encoding='utf-8') as codes_file:
    bpe = apply_bpe.BPE(codes_file, vocab=vocab)
    
with open(CORPUS_OUTPUT_PATH, mode='x', encoding='utf-8') as output_file:
  output_file.writelines(bpe.process_line(note) + '\n' for note in notes)

# %% [markdown]
# ### Glove embeddings

# %%
### Require steps to generate corpus and vocab when not using subwords ###

# %%
CORPUS_OUTPUT_PATH = os.path.join(DATA_PATH, 'glove', 'corpus.txt')

with open(CORPUS_OUTPUT_PATH, mode='w', encoding='utf-8') as output_file:
    output_file.writelines(note + '\n' for note in notes)

# %%
VOCAB_PATH = os.path.join(PROJECT_HOME_PATH, 'subwords', 'vocab.txt')

vocab_threshold = 20000

words_lst = [word.split(' ') for word in notes]
words_lst_flatten = [item for sublist in words_lst for item in sublist]
words_lst_flatten = pd.Series(words_lst_flatten)
vocab = words_lst_flatten.value_counts()

vocab[:vocab_threshold].to_csv(VOCAB_PATH, sep=' ', index=True, header=False)

# %% [markdown]
# #### Download GloVe repository

# %%
glove_repo_link = 'https://github.com/stanfordnlp/GloVe.git'

print(f'Please download GloVe project from the repository and place it under PROJECT_HOME_PATH: {glove_repo_link}')
# Out:
# Please download GloVe project from the repository and place it under PROJECT_HOME_PATH: https://github.com/stanfordnlp/GloVe.git

# %%
os.chdir(PROJECT_HOME_PATH)
# Out:
# /content/gdrive/My Drive/LSTM-light

# %%
# !git clone https://github.com/stanfordnlp/GloVe.git
# Out:
# Cloning into 'GloVe'...
# remote: Enumerating objects: 431, done.
# remote: Total 431 (delta 0), reused 0 (delta 0), pack-reused 431
# Receiving objects: 100% (431/431), 176.26 KiB | 867.00 KiB/s, done.
# Resolving deltas: 100% (236/236), done.

# %%
GLOVE_PATH = os.path.join(PROJECT_HOME_PATH, 'GloVe')

# %% [markdown]
# #### Execute make

# %%
from subprocess import Popen, PIPE
import subprocess

# %%
#TODO: Describe what make is for

# %%
def execute_script(file_path):
    p = Popen(['./{}'.format(file_path)], stdin=PIPE, stdout=PIPE, stderr=PIPE)
    output, err = p.communicate()
    rc = p.returncode
    return output, err

# %%
# make GloVe

if not os.path.exists(GLOVE_PATH):
    print(f'Please download GloVe project from the respository and place it under: {GLOVE_PATH}')
else:
    os.chdir(GLOVE_PATH)
    file_name = 'build_glove.sh'
    with open('./{}'.format(file_name), 'w') as file_handle:
        file_handle.write('#!/bin/bash\n')
        file_handle.write('cd {}\n'.format(GLOVE_PATH))
        file_handle.write('make\n')
    os.chmod(file_name, 0o777)
    print('Executing make')
    output, err = execute_script('./{}'.format(file_name))
    print('./{}'.format(file_name))
    os.remove(file_name)
    print('Finished')
# Out:
# Executing make
# ./build_glove.sh
# Finished

# %%
GLOVE_BIN_PATH = os.path.join(PROJECT_HOME_PATH, 'GloVe', 'build')

# %% [markdown]
# ### Generate co-occurrence statistics

# %% [markdown]
# The GloVe model is trained on the non-zero entries of a global word-word co-occurrence matrix, which tabulates how frequently words co-occur with one another in a given corpus. Populating this matrix requires a single pass through the entire corpus to collect the statistics. For large corpora, this pass can be computationally expensive, but it is a one-time up-front cost.
#
# The core training code is separated from these preprocessing steps and can be executed  independently.

# %%
subwords_symbols = 0
subwords_min_frequency = 0
glove_windows_size = 15
glove_iterations = 15
glove_vector_size = 50

# %%
subwords_params = str(subwords_symbols) + '_' + str(subwords_min_frequency)
cooccur_params = str(subwords_params) + '_' + str(glove_windows_size)
COOCCUR_PATH = os.path.join(DATA_PATH, 'glove', f'cooccurrence_{cooccur_params}')

# %%
def run_cooccur(vocab_path, corpus_path, cooccur_output_path, windows_size=15, verbose=False):
    
    if os.path.splitext(cooccur_output_path)[1]:
            raise ValueError(f'cooccur_output_path must not have any extension: {cooccur_output_path}')
    cooccur_output_path = cooccur_output_path + '.bin'
    cooccur_shuf_path = cooccur_output_path.replace('.bin', '.shuf.bin')

    subprocess.check_call(
        os.path.join(GLOVE_BIN_PATH, 'cooccur') +
        f' -vocab-file {vocab_path} -window-size {windows_size} -verbose {2 if verbose else 0}'
        f' < {corpus_path} > {cooccur_output_path}',
        shell=True
        )


    subprocess.check_call(
        os.path.join(GLOVE_BIN_PATH, 'shuffle') +
        f' -verbose {2 if verbose else 0} < {cooccur_output_path} > {cooccur_shuf_path}',
        shell=True
        )

# %%
run_cooccur(VOCAB_PATH, CORPUS_OUTPUT_PATH, COOCCUR_PATH, windows_size=glove_windows_size)

# %% [markdown]
# ### Train GloVe embeddings

# %%
glove_params = str(cooccur_params) + '_' + str(glove_iterations) + '_' + str(glove_vector_size)
VECTORS_PATH = os.path.join(DATA_PATH, 'glove', f'vectors_{glove_params}')

# %%
def run_glove(cooccur_path, vocab_path, vectors_output_path, vector_size=50, iterations=15,
             learning_rate=0.05, x_max=100, alpha=0.75, verbose=False, word2vec_format=False):
    if os.path.splitext(vectors_output_path)[1]:
        raise ValueError(f'vectors_output_path must not have any extansions: {vectors_output_path}')
        
    cooccur_path = cooccur_path + '.shuf.bin'
    threads = os.cpu_count()
    
    # glove automatically adds extension
    vectors_output_path = vectors_output_path.replace('.txt.', '')
    subprocess.check_call(
        os.path.join(GLOVE_BIN_PATH, 'glove') +
        f' -input-file {cooccur_path} -vocab-file {vocab_path} -write-header {int(word2vec_format)}'
        f' -vector-size {vector_size} -iter {iterations} -eta {learning_rate} -x-max {x_max}'
        f' -alpha {alpha} -threads {threads} -save-file {vectors_output_path}'
        f' -verbose {2 if verbose else 0}',
        shell=True
    )

# %%
run_glove(COOCCUR_PATH, VOCAB_PATH, VECTORS_PATH, vector_size=glove_vector_size)

# %%
### Visualize embeddings in Tensorboard

# %%
import tensorflow as tf
from tensorboard import main as tb
from tensorflow.contrib.tensorboard.plugins import projector

# %%
VECTORS_FILE_PATH = VECTORS_PATH + '.txt'
words, embeddings = [], []

with open(VECTORS_FILE_PATH, encoding='utf-8') as input_file:
    for line in input_file:
        word, *embedding = line.split()
        words.append(word)
        embeddings.append(np.array(embedding, dtype=float))
embeddings = np.array(embeddings)

# %%
print(f'\tembeddings shape: {embeddings.shape}\n\twords len: {len(words)}' )
# Out:
# 	embeddings shape: (9992, 50)
# 	words len: 9992

# %%
TENSORBOARD_PATH = os.path.join(DATA_PATH, 'tensorboard')

# %%
def save_for_projector(vectors, tensorboard_output_path, metadata, name):
    metadata_output_path = os.path.join(tensorboard_output_path, 'metadata.tsv')
    model_checkpoint_path = os.path.join(tensorboard_output_path, 'model.ckpt')
    
    # if more than one column: first row must be deader row
    with open(metadata_output_path, 'w', encoding='utf-8') as output_file:
        output_file.writelines(word + '\n' for word in metadata)
        
    session = tf.InteractiveSession()
    with tf.device("/cpu:0"):
        vectors_var = tf.Variable(vectors, name=name, trainable=False)
        
    tf.global_variables_initializer().run()
    saver = tf.train.Saver()
    writer = tf.summary.FileWriter(tensorboard_output_path)
    config = projector.ProjectorConfig()
    config.model_checkpoint_path = model_checkpoint_path
    embedding = config.embeddings.add()
    embedding.tensor_name = vectors_var.name
    embedding.metadata_path = metadata_output_path
    projector.visualize_embeddings(writer, config)
    saver.save(session, model_checkpoint_path)

# %%
len(words)
# Out:
# 9992

# %%
save_for_projector(embeddings, TENSORBOARD_PATH, words, name='embeddings')
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py:1702: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '

# %%
# Run tensorboard

# In terminal:
#$tensorboard --logdir=TENSORBOARD_PATH --port=6009

# If you run tensorboard on server, use port forwarding when log in: ssh [login@server] -L [port]:localhost:[port]
